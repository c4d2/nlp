# %%
import re
str = "自然语言很重要  abcdefg"

# %%
pattern = re.compile(r'.')

# %%
re.findall(pattern,str)
# Out:
# ['自', '然', '语', '言', '很', '重', '要']

# %%
pattern = re.compile(r'[abd]')
re.findall(pattern,str)
# Out:
# ['a', 'b', 'd']

# %% [markdown]
# ![image.png](attachment:image.png)
